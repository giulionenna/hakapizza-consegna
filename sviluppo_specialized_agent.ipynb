# %%
from langchain_ibm import ChatWatsonx
from langchain_openai import ChatOpenAI
from ibm_watsonx_ai.foundation_models import ModelInference
from langgraph.prebuilt import create_react_agent
from langchain_core.tools import tool
from credentials import *
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from typing import Literal, Annotated
import json
from pymongo import MongoClient
from typing import List, Dict

# llm = ChatWatsonx(
#     model_id="meta-llama/llama-3-3-70b-instruct",
#     url = ENDPOINT_URL,
# 	apikey = API_KEY,
# 	project_id = PROJECT_ID,
#     params = {
#         "decoding_method": "greedy",
#         "temperature": 0, 
#         "min_new_tokens": 5, 
#         "max_new_tokens": 2000
#     }
# )
llm = ChatOpenAI(
    model="gpt-4o",
    seed=420,
    temperature=0.01
)

llm.invoke([HumanMessage("Hello")])
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpcore\_sync\connection.py:156, in HTTPConnection._connect(self, request)
#     155 with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156     stream = stream.start_tls(**kwargs)
#     157     trace.return_value = stream
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpcore\_backends\sync.py:154, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     150 exc_map: ExceptionMapping = {
#     151     socket.timeout: ConnectTimeout,
#     152     OSError: ConnectError,
#     153 }
# --> 154 with map_exceptions(exc_map):
#     155     try:
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\openai\_base_client.py:996, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     995 try:
# --> 996     response = self._client.send(
#     997         request,
#     998         stream=stream or self._should_stream_response_body(request=request),
#     999         **kwargs,
#    1000     )
#    1001 except httpx.TimeoutException as err:
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[83], line 31
#      13 # llm = ChatWatsonx(
#      14 #     model_id="meta-llama/llama-3-3-70b-instruct",
#      15 #     url = ENDPOINT_URL,
#    (...)
#      23 #     }
#      24 # )
#      25 llm = ChatOpenAI(
#      26     model="gpt-4o",
#      27     seed=420,
#      28     temperature=0.01
#      29 )
# ---> 31 llm.invoke([HumanMessage("Hello")])
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\langchain_core\language_models\chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\langchain_core\language_models\chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\langchain_core\language_models\chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\langchain_openai\chat_models\base.py:781, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     779     generation_info = {"headers": dict(raw_response.headers)}
#     780 else:
# --> 781     response = self.client.create(**payload)
#     782 return self._create_chat_result(response, generation_info)
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\openai\resources\chat\completions.py:859, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     817 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     818 def create(
#     819     self,
#    (...)
#     856     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     857 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     858     validate_response_format(response_format)
# --> 859     return self._post(
#     860         "/chat/completions",
#     861         body=maybe_transform(
#     862             {
#     863                 "messages": messages,
#     864                 "model": model,
#     865                 "audio": audio,
#     866                 "frequency_penalty": frequency_penalty,
#     867                 "function_call": function_call,
#     868                 "functions": functions,
#     869                 "logit_bias": logit_bias,
#     870                 "logprobs": logprobs,
#     871                 "max_completion_tokens": max_completion_tokens,
#     872                 "max_tokens": max_tokens,
#     873                 "metadata": metadata,
#     874                 "modalities": modalities,
#     875                 "n": n,
#     876                 "parallel_tool_calls": parallel_tool_calls,
#     877                 "prediction": prediction,
#     878                 "presence_penalty": presence_penalty,
#     879                 "reasoning_effort": reasoning_effort,
#     880                 "response_format": response_format,
#     881                 "seed": seed,
#     882                 "service_tier": service_tier,
#     883                 "stop": stop,
#     884                 "store": store,
#     885                 "stream": stream,
#     886                 "stream_options": stream_options,
#     887                 "temperature": temperature,
#     888                 "tool_choice": tool_choice,
#     889                 "tools": tools,
#     890                 "top_logprobs": top_logprobs,
#     891                 "top_p": top_p,
#     892                 "user": user,
#     893             },
#     894             completion_create_params.CompletionCreateParams,
#     895         ),
#     896         options=make_request_options(
#     897             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     898         ),
#     899         cast_to=ChatCompletion,
#     900         stream=stream or False,
#     901         stream_cls=Stream[ChatCompletionChunk],
#     902     )
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\openai\_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\openai\_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\openai\_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1017 log.debug("Encountered Exception", exc_info=True)
#    1019 if remaining_retries > 0:
# -> 1020     return self._retry_request(
#    1021         input_options,
#    1022         cast_to,
#    1023         retries_taken=retries_taken,
#    1024         stream=stream,
#    1025         stream_cls=stream_cls,
#    1026         response_headers=None,
#    1027     )
#    1029 log.debug("Raising connection error")
#    1030 raise APIConnectionError(request=request) from err
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\openai\_base_client.py:1098, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1094 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1095 # different thread if necessary.
#    1096 time.sleep(timeout)
# -> 1098 return self._request(
#    1099     options=options,
#    1100     cast_to=cast_to,
#    1101     retries_taken=retries_taken + 1,
#    1102     stream=stream,
#    1103     stream_cls=stream_cls,
#    1104 )
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\openai\_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1017 log.debug("Encountered Exception", exc_info=True)
#    1019 if remaining_retries > 0:
# -> 1020     return self._retry_request(
#    1021         input_options,
#    1022         cast_to,
#    1023         retries_taken=retries_taken,
#    1024         stream=stream,
#    1025         stream_cls=stream_cls,
#    1026         response_headers=None,
#    1027     )
#    1029 log.debug("Raising connection error")
#    1030 raise APIConnectionError(request=request) from err
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\openai\_base_client.py:1098, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1094 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1095 # different thread if necessary.
#    1096 time.sleep(timeout)
# -> 1098 return self._request(
#    1099     options=options,
#    1100     cast_to=cast_to,
#    1101     retries_taken=retries_taken + 1,
#    1102     stream=stream,
#    1103     stream_cls=stream_cls,
#    1104 )
#
# File c:\Users\g.nenna\AppData\Local\anaconda3\envs\hakapizza\Lib\site-packages\openai\_base_client.py:1030, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1020         return self._retry_request(
#    1021             input_options,
#    1022             cast_to,
#    (...)
#    1026             response_headers=None,
#    1027         )
#    1029     log.debug("Raising connection error")
# -> 1030     raise APIConnectionError(request=request) from err
#    1032 log.debug(
#    1033     'HTTP Response: %s %s "%i %s" %s',
#    1034     request.method,
#    (...)
#    1038     response.headers,
#    1039 )
#    1040 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %%
import os

os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
query_translation_prompt = """
You are given a query in natural language and a json schema. The json schema is the schema of the json documents in a MongoDB collection that will be queried. You will translate the natural language query into a series of mongoDB queries. The queries will be executed with an "aggregate" function. You only have to return the mongodb queries, not the python code. since queries will be executed with an aggregate function, you can use any of the aggregate operators. Most of the times the query is not a simle filter but requires also a particolar view of the result (maybe pivots using the $unwind operator).

JSON SCHEMA:
{json_schema}

NATURAL LANGUAGE QUERY:
{query}
"""

query_translation_schema={
"title": "Query_Translation",
"description": "Translate a natural language query into a series of MongoDB queries that will be executed with an aggregate function",
  "type": "object",
  "properties": {
    "queries": {
      "description" : "A series of MongoDB queries that will be executed with an aggregate function",
      "type": "array",
      "items": {
        "type": "string",
        "description": "A MongoDB query, must be a key-value pair enclosed in curly braces."
      }
    }
  },
  "required": ["queries"],
  "additionalProperties": False
}

translation_llm = llm.with_structured_output(query_translation_schema)

with open('output/Menu/schema.json', 'r') as file:
    json_schema = file.read()

with open('output/Menu/description.txt', 'r') as file:
    collection_description = file.read()

collection_description_prompt = """
You are an agent that needs to answer queries from a set of documents. Here is a description of the document collection you will be working with:
{collection_description}
You need to use the tools that you are given to answer queries about the document collection. 
"""

system_prompt = collection_description_prompt.format(collection_description=collection_description)
# Connect to the local MongoDB server (default URI)
client = MongoClient("mongodb://localhost:27017/")

# Access a specific database (it will be created if it doesn't exist)
db = client["hackapizza"]

# Access a specific collection within the database
collection = db["Menu"]

# %%
for doc in collection.aggregate([
    {'$unwind': '$menu'}, {'$unwind': '$menu.ingredients'}, 
    {'$match': {'menu.ingredients.name': 'Amido di Stellarion'}}, 
    {'$project': {'_id': 0, 'dish_name': '$menu.dish_name'}}
]):
    print(doc)

# %%
translation_llm.invoke(query_translation_prompt.format(json_schema=json_schema, query="Quali piatti contengono Amido di Stellarion?"))
# Out:
# {'queries': [{'$unwind': '$restaurants'},
#   {'$unwind': '$restaurants.menu'},
#   {'$unwind': '$restaurants.menu.ingredients'},
#   {'$match': {'restaurants.menu.ingredients.name': 'Amido di Stellarion'}},
#   {'$project': {'_id': 0, 'dish_name': '$restaurants.menu.dish_name'}}]}

# %%
@tool
def translate_query_into_mongo(query : str)-> List[Dict[str,str]]:
    """function that takes a query in natural language and queries the mongodb"""
    prompt = query_translation_prompt.format(json_schema=json_schema, query=query)
    result = translation_llm.invoke(prompt)
    
    final_list = []

    for query in result["queries"]:
        try:
            if type(query) == str:
                final_list.append(eval(query))
            else:
                final_list.append(query)
        except Exception as e:
            print(f"Error: {query}")
            print(e)
            continue

    result = collection.aggregate(final_list)

# Itera sui risultati
    res = ""
    for doc in result:
        res += str(doc)
        print(doc)
    return res


@tool
def query_mongo(queries: List[Dict[str, str]])-> str:
    """function that takes a list of mongodb queries and executes the queries on the mongodb. returns the result of the queries"""
    return_string = ""
    print(f"queries: {type(queries[0])}")
    res = collection.aggregate(queries)
    for doc in res:
        return_string += str(doc)
        print(doc)
    return return_string

# %%
query = "Quali piatti contengono Amido di Stellarion?"
prompt = query_translation_prompt.format(json_schema=json_schema, query=query)
result = translation_llm.invoke(prompt)
result['queries']
# Out:
# ['{ "$unwind": "$restaurants" }',
#  '{ "$unwind": "$restaurants.menu" }',
#  '{ "$unwind": "$restaurants.menu.ingredients" }',
#  '{ "$match": { "restaurants.menu.ingredients.name": "Amido di Stellarion" } }',
#  '{ "$project": { "dish_name": "$restaurants.menu.dish_name", "description": "$restaurants.menu.description", "price": "$restaurants.menu.price" } }']

# %%
eval(result['queries'][0])
# Out:
# {'$unwind': '$restaurants'}

# %%
agent = create_react_agent(llm, [translate_query_into_mongo], state_modifier=SystemMessage(system_prompt))

# %%
agent.invoke({'messages': HumanMessage('Quali piatti contengono Amido di Stellarion?')})
# Out:
# {'dish_name': 'Pizza Fra'}
# {'dish_name': 'Sinfonia Tempolare Galattica'}
# {'dish_name': 'Rinascita Cosmica'}
# {'dish_name': "Pizza Cosmica all'Essenza di Drago con Nebbia Arcobaleno e Funghi Orbitali"}
# {'dish_name': 'Nebulosa di Drago Interdimensionale'}
# {'dish_name': 'Cosmic Serenade'}
# {'dish_name': 'Ecosistema Celeste'}
# {'dish_name': 'Nebulosa Celestiale di Sogni Quantici'}
# {'dish_name': 'Galassia Ardente'}
# {'dish_name': 'Galassia di Cosmo-Delizie'}
# {'dish_name': 'Nebulosa di Confini Sfondati'}
# {'dish_name': 'Cosmos Risotto Reale'}
# {'messages': [HumanMessage(content='Quali piatti contengono Amido di Stellarion?', additional_kwargs={}, response_metadata={}, id='02f417fc-5fa2-406b-9abe-dd22c4c567bb'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_gGKCGIC6dmy9b6p446uPcdGL', 'function': {'arguments': '{"query":"Quali piatti contengono Amido di Stellarion?"}', 'name': 'translate_query_into_mongo'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 855, 'total_tokens': 885, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_50cad350e4', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-879614cc-fcf9-4a08-8a3a-dc8b17740131-0', tool_calls=[{'name': 'translate_query_into_mongo', 'args': {'query': 'Quali piatti contengono Amido di Stellarion?'}, 'id': 'call_gGKCGIC6dmy9b6p446uPcdGL', 'type': 'tool_call'}], usage_metadata={'input_tokens': 855, 'output_tokens': 30, 'total_tokens': 885, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{\'dish_name\': \'Pizza Fra\'}{\'dish_name\': \'Sinfonia Tempolare Galattica\'}{\'dish_name\': \'Rinascita Cosmica\'}{\'dish_name\': "Pizza Cosmica all\'Essenza di Drago con Nebbia Arcobaleno e Funghi Orbitali"}{\'dish_name\': \'Nebulosa di Drago Interdimensionale\'}{\'dish_name\': \'Cosmic Serenade\'}{\'dish_name\': \'Ecosistema Celeste\'}{\'dish_name\': \'Nebulosa Celestiale di Sogni Quantici\'}{\'dish_name\': \'Galassia Ardente\'}{\'dish_name\': \'Galassia di Cosmo-Delizie\'}{\'dish_name\': \'Nebulosa di Confini Sfondati\'}{\'dish_name\': \'Cosmos Risotto Reale\'}', name='translate_query_into_mongo', id='8922721c-e668-4d9e-a3ad-61bec5c81b41', tool_call_id='call_gGKCGIC6dmy9b6p446uPcdGL'),
#   AIMessage(content="I piatti che contengono Amido di Stellarion sono:\n\n1. Pizza Fra\n2. Sinfonia Tempolare Galattica\n3. Rinascita Cosmica\n4. Pizza Cosmica all'Essenza di Drago con Nebbia Arcobaleno e Funghi Orbitali\n5. Nebulosa di Drago Interdimensionale\n6. Cosmic Serenade\n7. Ecosistema Celeste\n8. Nebulosa Celestiale di Sogni Quantici\n9. Galassia Ardente\n10. Galassia di Cosmo-Delizie\n11. Nebulosa di Confini Sfondati\n12. Cosmos Risotto Reale", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 143, 'prompt_tokens': 1063, 'total_tokens': 1206, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_50cad350e4', 'finish_reason': 'stop', 'logprobs': None}, id='run-2e867304-50f0-4d6f-8ed4-87f8f65d5a4d-0', usage_metadata={'input_tokens': 1063, 'output_tokens': 143, 'total_tokens': 1206, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
class CreateSpecializedAgent:
    def __init__(self, llm, json_schema, collection_description, mongo_uri = "mongodb://localhost:27017/", db_name = "hackapizza", collection_name = "Documents_1"):
        self.llm = llm
        self.json_schema = json_schema
        self.collection_description = collection_description
        self.client = MongoClient(mongo_uri)
        self.db = self.client[db_name]
        self.collection = self.db[collection_name]

        collection_description_prompt = """
        You are an agent that needs to answer queries from a set of documents. Here is a description of the document collection you will be working with:
        {collection_description}
        You need to use the tools that you are given to answer queries about the document collection. 
        """

        self.query_translation_prompt = """
        You are given a query in natural language and a json schema. The json schema is the schema of the json documents in a MongoDB collection that will be queried. You will translate the natural language query into a series of mongoDB queries. The queries will be executed with an "aggregate" function. You only have to return the mongodb queries, not the python code. since queries will be executed with an aggregate function, you can use any of the aggregate operators. Most of the times the query is not a simle filter but requires also a particolar view of the result (maybe pivots using the $unwind operator).

        JSON SCHEMA:
        {json_schema}

        NATURAL LANGUAGE QUERY:
        {query}
        """

        self.query_translation_schema={
        "title": "Query_Translation",
        "description": "Translate a natural language query into a series of MongoDB queries that will be executed with an aggregate function",
        "type": "object",
        "properties": {
            "queries": {
            "type": "array",
            "items": {
                "type": "string",
                "description": "A MongoDB query, must be a key-value pair enclosed in curly braces. both key and value must be strings enclosed in double quotes"
            }
            }
        },
        "required": ["queries"],
        "additionalProperties": False
        }

        collection_description_prompt = """
        You are an agent that needs to answer queries from a set of documents. Here is a description of the document collection you will be working with:
        {collection_description}
        You need to use the tools that you are given to answer queries about the document collection. 
        """
        
        self.translation_llm = llm.with_structured_output(self.query_translation_schema)
        self.system_prompt = collection_description_prompt.format(collection_description=collection_description)
        
        @tool
        def translate_query_into_mongo(query : Annotated[str,"the natural language query that will be translated in a list of mongodb queries to be executed"])-> List[dict]:
            """function that takes a query in natural language and returns a list of mongodb queries to execute. This tool is needed to query the document base to answer the user's query"""
            prompt = self.query_translation_prompt.format(json_schema=self.json_schema, query=query)
            result = self.translation_llm.invoke(prompt)
            queries = result["queries"]
            print(queries)
            return queries
        
        @tool
        def query_mongo(queries: Annotated[List[dict], "a list of dictionaries with key-value pair"])-> str:
            """function that takes a list of mongodb queries and returns the result of the queries"""
            return_string = ""
            res = self.collection.aggregate(queries)
            for doc in res:
                return_string += str(doc)
                print(doc)
            return return_string
    
        self.agent = create_react_agent(self.llm, [translate_query_into_mongo, query_mongo], state_modifier=SystemMessage(self.system_prompt))

# %%
agent = CreateSpecializedAgent(llm, json_schema, collection_description).agent

# %%
agent.invoke({'messages': HumanMessage('piatti che non hanno il basilico')})
# Out:
# {'dishes': [{'dish_name': 'Pizza Cri', 'signatureDish': True, 'description': 'Fusilli del Vento con Funghi dellʼEtere e Uova di Fenice.', 'ingredients': {'name': 'Fusilli del Vento', 'origin': 'Correnti aeree'}, 'techniques': [{'name': 'Affumicatura a Stratificazione Quantica', 'effect': 'Profumo cosmico'}, {'name': 'Sferificazione con Campi Magnetici Entropici', 'effect': 'Variazioni di texture'}, {'name': 'Microonde Entropiche Sincronizzate', 'effect': 'Cottura bilanciata'}], 'pairings': [{'beverage': 'Liquido Arcobaleno', 'notes': 'Esplosione di sapori e colori'}], 'price': '260 crediti galattici', 'notes': 'Un capolavoro multisensoriale.'}, {'dish_name': 'Pizza Cri', 'signatureDish': True, 'description': 'Fusilli del Vento con Funghi dellʼEtere e Uova di Fenice.', 'ingredients': {'name': 'Funghi dellʼEtere', 'origin': 'Nubi astrali'}, 'techniques': [{'name': 'Affumicatura a Stratificazione Quantica', 'effect': 'Profumo cosmico'}, {'name': 'Sferificazione con Campi Magnetici Entropici', 'effect': 'Variazioni di texture'}, {'name': 'Microonde Entropiche Sincronizzate', 'effect': 'Cottura bilanciata'}], 'pairings': [{'beverage': 'Liquido Arcobaleno', 'notes': 'Esplosione di sapori e colori'}], 'price': '260 crediti galattici', 'notes': 'Un capolavoro multisensoriale.'}, {'dish_name': 'Pizza Cri', 'signatureDish': True, 'description': 'Fusilli del Vento con Funghi dellʼEtere e Uova di Fenice.', 'ingredients': {'name': 'Uova di Fenice', 'origin': 'Bestie mitologiche'}, 'techniques': [{'name': 'Affumicatura a Stratificazione Quantica', 'effect': 'Profumo cosmico'}, {'name': 'Sferificazione con Campi Magnetici Entropici', 'effect': 'Variazioni di texture'}, {'name': 'Microonde Entropiche Sincronizzate', 'effect': 'Cottura bilanciata'}], 'pairings': [{'beverage': 'Liquido Arcobaleno', 'notes': 'Esplosione di sapori e colori'}], 'price': '260 crediti galattici', 'notes': 'Un capolavoro multisensoriale.'}], 'dish_name': 'Pizza Cri'}
# {'dishes': [{'dish_name': 'Galassia Infinita: Viaggio tra Memorie e Stelle', 'signatureDish': True, 'description': "Un'esplorazione sinfonica di sfere celesti e ricordi.", 'ingredients': {'name': 'Cristalli di Memoria', 'origin': 'Galassia Mnemotica'}, 'techniques': [{'name': 'Marinatura Temporale Sincronizzata', 'effect': 'Accelera la maturazione'}, {'name': 'Sferificazione tramite Matrici Biofotiche', 'effect': 'Crea esplosioni di emozioni'}], 'pairings': [{'beverage': 'Vino Temporale', 'notes': 'Invecchiato istantaneamente'}], 'price': '200 crediti galattici', 'notes': 'Viaggio interdimensionale nei sapori.'}, {'dish_name': 'Galassia Infinita: Viaggio tra Memorie e Stelle', 'signatureDish': True, 'description': "Un'esplorazione sinfonica di sfere celesti e ricordi.", 'ingredients': {'name': 'Spore Quantiche', 'origin': 'Dimensione Quantica'}, 'techniques': [{'name': 'Marinatura Temporale Sincronizzata', 'effect': 'Accelera la maturazione'}, {'name': 'Sferificazione tramite Matrici Biofotiche', 'effect': 'Crea esplosioni di emozioni'}], 'pairings': [{'beverage': 'Vino Temporale', 'notes': 'Invecchiato istantaneamente'}], 'price': '200 crediti galattici', 'notes': 'Viaggio interdimensionale nei sapori.'}, {'dish_name': 'Galassia Infinita: Viaggio tra Memorie e Stelle', 'signatureDish': True, 'description': "Un'esplorazione sinfonica di sfere celesti e ricordi.", 'ingredients': {'name': 'Essenza di Tachioni', 'origin': 'Flusso Temporale'}, 'techniques': [{'name': 'Marinatura Temporale Sincronizzata', 'effect': 'Accelera la maturazione'}, {'name': 'Sferificazione tramite Matrici Biofotiche', 'effect': 'Crea esplosioni di emozioni'}], 'pairings': [{'beverage': 'Vino Temporale', 'notes': 'Invecchiato istantaneamente'}], 'price': '200 crediti galattici', 'notes': 'Viaggio interdimensionale nei sapori.'}, {'dish_name': 'Galassia Infinita: Viaggio tra Memorie e Stelle', 'signatureDish': True, 'description': "Un'esplorazione sinfonica di sfere celesti e ricordi.", 'ingredients': {'name': 'Pane di Luce', 'origin': 'Stella lontana'}, 'techniques': [{'name': 'Marinatura Temporale Sincronizzata', 'effect': 'Accelera la maturazione'}, {'name': 'Sferificazione tramite Matrici Biofotiche', 'effect': 'Crea esplosioni di emozioni'}], 'pairings': [{'beverage': 'Vino Temporale', 'notes': 'Invecchiato istantaneamente'}], 'price': '200 crediti galattici', 'notes': 'Viaggio interdimensionale nei sapori.'}], 'dish_name': 'Galassia Infinita: Viaggio tra Memorie e Stelle'}
# {'dishes': [{'dish_name': 'Rivisitazione del Kraken sotto Molecole', 'signatureDish': True, 'description': 'Carne di Kraken esaltata da Grigliatura a Energia Stellare DiV, accompagnata da salsa di Colonia di Mycoflora e Spezie Melange.', 'ingredients': {'name': 'Carne di Kraken', 'origin': 'Mari Dimensionali'}, 'techniques': [{'name': 'Grigliatura a Energia Stellare DiV', 'effect': 'Esaltazione toni salmastri'}, {'name': 'Amalgamazione Sintetica Molecolare', 'effect': 'Unione complessità sapori'}], 'pairings': [{'beverage': 'Nettare di Comete', 'notes': 'Completare i sapori stellari'}], 'price': '20 crediti galattici', 'notes': 'Offre un viaggio tra le stelle'}, {'dish_name': 'Rivisitazione del Kraken sotto Molecole', 'signatureDish': True, 'description': 'Carne di Kraken esaltata da Grigliatura a Energia Stellare DiV, accompagnata da salsa di Colonia di Mycoflora e Spezie Melange.', 'ingredients': {'name': 'Colonia di Mycoflora', 'origin': 'Foreste Stellari'}, 'techniques': [{'name': 'Grigliatura a Energia Stellare DiV', 'effect': 'Esaltazione toni salmastri'}, {'name': 'Amalgamazione Sintetica Molecolare', 'effect': 'Unione complessità sapori'}], 'pairings': [{'beverage': 'Nettare di Comete', 'notes': 'Completare i sapori stellari'}], 'price': '20 crediti galattici', 'notes': 'Offre un viaggio tra le stelle'}, {'dish_name': 'Rivisitazione del Kraken sotto Molecole', 'signatureDish': True, 'description': 'Carne di Kraken esaltata da Grigliatura a Energia Stellare DiV, accompagnata da salsa di Colonia di Mycoflora e Spezie Melange.', 'ingredients': {'name': 'Spezie Melange', 'origin': 'Pianeti Speziati'}, 'techniques': [{'name': 'Grigliatura a Energia Stellare DiV', 'effect': 'Esaltazione toni salmastri'}, {'name': 'Amalgamazione Sintetica Molecolare', 'effect': 'Unione complessità sapori'}], 'pairings': [{'beverage': 'Nettare di Comete', 'notes': 'Completare i sapori stellari'}], 'price': '20 crediti galattici', 'notes': 'Offre un viaggio tra le stelle'}], 'dish_name': 'Rivisitazione del Kraken sotto Molecole'}
# {'dishes': [{'dish_name': 'Eterea Sinfonia di Gravità con Infusione Temporale', 'signatureDish': False, 'description': 'Un filetto mistico che esplora il continuum spazio-temporale.', 'ingredients': {'name': 'Radici di Gravità', 'origin': 'Foreste di Andromeda'}, 'techniques': [{'name': 'Congelazione Iperdimensionalmente Stratificata', 'effect': 'Mantiene intatta ogni componente a livello subatomico.'}, {'name': 'Sinergia Elettro-Osmotica Programmabile', 'effect': 'Penetra la carne con aromi elettromagnetici.'}], 'pairings': [{'beverage': 'Nettare degli Orizzonti', 'notes': 'Bilancia la composizione eterea.'}], 'price': '180 cristalli di sabbia', 'notes': 'La tecnica di infusione garantisce una complessità sorprendente.'}, {'dish_name': 'Eterea Sinfonia di Gravità con Infusione Temporale', 'signatureDish': False, 'description': 'Un filetto mistico che esplora il continuum spazio-temporale.', 'ingredients': {'name': 'Carne di Xenodonte', 'origin': 'Pianeta Xenon'}, 'techniques': [{'name': 'Congelazione Iperdimensionalmente Stratificata', 'effect': 'Mantiene intatta ogni componente a livello subatomico.'}, {'name': 'Sinergia Elettro-Osmotica Programmabile', 'effect': 'Penetra la carne con aromi elettromagnetici.'}], 'pairings': [{'beverage': 'Nettare degli Orizzonti', 'notes': 'Bilancia la composizione eterea.'}], 'price': '180 cristalli di sabbia', 'notes': 'La tecnica di infusione garantisce una complessità sorprendente.'}, {'dish_name': 'Eterea Sinfonia di Gravità con Infusione Temporale', 'signatureDish': False, 'description': 'Un filetto mistico che esplora il continuum spazio-temporale.', 'ingredients': {'name': 'Essenza di Tachioni', 'origin': 'Laboratorio quantico'}, 'techniques': [{'name': 'Congelazione Iperdimensionalmente Stratificata', 'effect': 'Mantiene intatta ogni componente a livello subatomico.'}, {'name': 'Sinergia Elettro-Osmotica Programmabile', 'effect': 'Penetra la carne con aromi elettromagnetici.'}], 'pairings': [{'beverage': 'Nettare degli Orizzonti', 'notes': 'Bilancia la composizione eterea.'}], 'price': '180 cristalli di sabbia', 'notes': 'La tecnica di infusione garantisce una complessità sorprendente.'}, {'dish_name': 'Eterea Sinfonia di Gravità con Infusione Temporale', 'signatureDish': False, 'description': 'Un filetto mistico che esplora il continuum spazio-temporale.', 'ingredients': {'name': 'Funghi dell’Etere', 'origin': 'Pianeta Mysticor'}, 'techniques': [{'name': 'Congelazione Iperdimensionalmente Stratificata', 'effect': 'Mantiene intatta ogni componente a livello subatomico.'}, {'name': 'Sinergia Elettro-Osmotica Programmabile', 'effect': 'Penetra la carne con aromi elettromagnetici.'}], 'pairings': [{'beverage': 'Nettare degli Orizzonti', 'notes': 'Bilancia la composizione eterea.'}], 'price': '180 cristalli di sabbia', 'notes': 'La tecnica di infusione garantisce una complessità sorprendente.'}], 'dish_name': 'Eterea Sinfonia di Gravità con Infusione Temporale'}
# {'dishes': [{'dish_name': "Nebulosa di Sapori dell'Infinito", 'signatureDish': True, 'description': 'Capolavoro gastronomico che trasforma il tempo e lo spazio.', 'ingredients': {'name': 'Lattuga Namecciana', 'origin': 'Orti di Namecc'}, 'techniques': [{'name': 'Congelamento Bio-Luminiscente Sincronico', 'effect': 'Presenta freschezza bertempale'}, {'name': 'Saltare in Padella Realtà Energetiche Parallele', 'effect': "Trasforma l'essenza dei sapori"}, {'name': 'Saltare in Padella Classica', 'effect': 'Intensifica sapori tradizionali'}, {'name': 'Fermentazione Quantico Biometrica', 'effect': 'Maturazione unica dello stato'}], 'pairings': [{'beverage': 'Succo di Stelle', 'notes': 'Perfetto per il bilanciamento della nebulosa'}], 'price': '260 Crediti Galattici', 'notes': 'Culminazione della cucina quantistica.'}, {'dish_name': "Nebulosa di Sapori dell'Infinito", 'signatureDish': True, 'description': 'Capolavoro gastronomico che trasforma il tempo e lo spazio.', 'ingredients': {'name': 'Carne di Xenodonte', 'origin': 'Pianure di Xenon'}, 'techniques': [{'name': 'Congelamento Bio-Luminiscente Sincronico', 'effect': 'Presenta freschezza bertempale'}, {'name': 'Saltare in Padella Realtà Energetiche Parallele', 'effect': "Trasforma l'essenza dei sapori"}, {'name': 'Saltare in Padella Classica', 'effect': 'Intensifica sapori tradizionali'}, {'name': 'Fermentazione Quantico Biometrica', 'effect': 'Maturazione unica dello stato'}], 'pairings': [{'beverage': 'Succo di Stelle', 'notes': 'Perfetto per il bilanciamento della nebulosa'}], 'price': '260 Crediti Galattici', 'notes': 'Culminazione della cucina quantistica.'}, {'dish_name': "Nebulosa di Sapori dell'Infinito", 'signatureDish': True, 'description': 'Capolavoro gastronomico che trasforma il tempo e lo spazio.', 'ingredients': {'name': 'Foglie di Nebulosa', 'origin': 'Campi Stellari'}, 'techniques': [{'name': 'Congelamento Bio-Luminiscente Sincronico', 'effect': 'Presenta freschezza bertempale'}, {'name': 'Saltare in Padella Realtà Energetiche Parallele', 'effect': "Trasforma l'essenza dei sapori"}, {'name': 'Saltare in Padella Classica', 'effect': 'Intensifica sapori tradizionali'}, {'name': 'Fermentazione Quantico Biometrica', 'effect': 'Maturazione unica dello stato'}], 'pairings': [{'beverage': 'Succo di Stelle', 'notes': 'Perfetto per il bilanciamento della nebulosa'}], 'price': '260 Crediti Galattici', 'notes': 'Culminazione della cucina quantistica.'}, {'dish_name': "Nebulosa di Sapori dell'Infinito", 'signatureDish': True, 'description': 'Capolavoro gastronomico che trasforma il tempo e lo spazio.', 'ingredients': {'name': 'Plasma Vitale', 'origin': 'Pozzi Vitali'}, 'techniques': [{'name': 'Congelamento Bio-Luminiscente Sincronico', 'effect': 'Presenta freschezza bertempale'}, {'name': 'Saltare in Padella Realtà Energetiche Parallele', 'effect': "Trasforma l'essenza dei sapori"}, {'name': 'Saltare in Padella Classica', 'effect': 'Intensifica sapori tradizionali'}, {'name': 'Fermentazione Quantico Biometrica', 'effect': 'Maturazione unica dello stato'}], 'pairings': [{'beverage': 'Succo di Stelle', 'notes': 'Perfetto per il bilanciamento della nebulosa'}], 'price': '260 Crediti Galattici', 'notes': 'Culminazione della cucina quantistica.'}, {'dish_name': "Nebulosa di Sapori dell'Infinito", 'signatureDish': True, 'description': 'Capolavoro gastronomico che trasforma il tempo e lo spazio.', 'ingredients': {'name': 'Nduja Fritta Tanto', 'origin': 'Cucine del Sud-Andromeda'}, 'techniques': [{'name': 'Congelamento Bio-Luminiscente Sincronico', 'effect': 'Presenta freschezza bertempale'}, {'name': 'Saltare in Padella Realtà Energetiche Parallele', 'effect': "Trasforma l'essenza dei sapori"}, {'name': 'Saltare in Padella Classica', 'effect': 'Intensifica sapori tradizionali'}, {'name': 'Fermentazione Quantico Biometrica', 'effect': 'Maturazione unica dello stato'}], 'pairings': [{'beverage': 'Succo di Stelle', 'notes': 'Perfetto per il bilanciamento della nebulosa'}], 'price': '260  ...
# {'dishes': [{'dish_name': 'Sinfonia Cosmica ma Fatta Male', 'signatureDish': False, 'description': 'Piatto che fonde scienza e arte culinaria, evocando mini-galassie vibranti.', 'ingredients': {'name': 'Radici di Singolarità', 'origin': 'Vicoli Temporali'}, 'techniques': [{'name': 'Affumicatura a Stratificazione Quantica', 'effect': 'Profondità aromatica unica'}, {'name': 'Cottura a Forno Dinamico Inversionale', 'effect': 'Aromi rilassanti e consistenza vellutata'}], 'pairings': [{'beverage': 'Infuso di Stelle Cadenti', 'notes': "Amplifica l'esperienza sensoriale"}], 'price': '250 crediti galattici', 'notes': 'Un viaggio sensoriale nelle dimensioni cosmiche'}, {'dish_name': 'Sinfonia Cosmica ma Fatta Male', 'signatureDish': False, 'description': 'Piatto che fonde scienza e arte culinaria, evocando mini-galassie vibranti.', 'ingredients': {'name': 'Granuli di Nebbia Arcobaleno', 'origin': 'Nebulose Cromatiche'}, 'techniques': [{'name': 'Affumicatura a Stratificazione Quantica', 'effect': 'Profondità aromatica unica'}, {'name': 'Cottura a Forno Dinamico Inversionale', 'effect': 'Aromi rilassanti e consistenza vellutata'}], 'pairings': [{'beverage': 'Infuso di Stelle Cadenti', 'notes': "Amplifica l'esperienza sensoriale"}], 'price': '250 crediti galattici', 'notes': 'Un viaggio sensoriale nelle dimensioni cosmiche'}, {'dish_name': 'Sinfonia Cosmica ma Fatta Male', 'signatureDish': False, 'description': 'Piatto che fonde scienza e arte culinaria, evocando mini-galassie vibranti.', 'ingredients': {'name': 'Lattuga Namecciana', 'origin': 'Giardini di Luce'}, 'techniques': [{'name': 'Affumicatura a Stratificazione Quantica', 'effect': 'Profondità aromatica unica'}, {'name': 'Cottura a Forno Dinamico Inversionale', 'effect': 'Aromi rilassanti e consistenza vellutata'}], 'pairings': [{'beverage': 'Infuso di Stelle Cadenti', 'notes': "Amplifica l'esperienza sensoriale"}], 'price': '250 crediti galattici', 'notes': 'Un viaggio sensoriale nelle dimensioni cosmiche'}, {'dish_name': 'Sinfonia Cosmica ma Fatta Male', 'signatureDish': False, 'description': 'Piatto che fonde scienza e arte culinaria, evocando mini-galassie vibranti.', 'ingredients': {'name': 'Baccacedro', 'origin': 'Piante Ancestrali'}, 'techniques': [{'name': 'Affumicatura a Stratificazione Quantica', 'effect': 'Profondità aromatica unica'}, {'name': 'Cottura a Forno Dinamico Inversionale', 'effect': 'Aromi rilassanti e consistenza vellutata'}], 'pairings': [{'beverage': 'Infuso di Stelle Cadenti', 'notes': "Amplifica l'esperienza sensoriale"}], 'price': '250 crediti galattici', 'notes': 'Un viaggio sensoriale nelle dimensioni cosmiche'}, {'dish_name': 'Sinfonia Cosmica ma Fatta Male', 'signatureDish': False, 'description': 'Piatto che fonde scienza e arte culinaria, evocando mini-galassie vibranti.', 'ingredients': {'name': 'Funghi dell’Etere', 'origin': 'Foreste di Pandora'}, 'techniques': [{'name': 'Affumicatura a Stratificazione Quantica', 'effect': 'Profondità aromatica unica'}, {'name': 'Cottura a Forno Dinamico Inversionale', 'effect': 'Aromi rilassanti e consistenza vellutata'}], 'pairings': [{'beverage': 'Infuso di Stelle Cadenti', 'notes': "Amplifica l'esperienza sensoriale"}], 'price': '250 crediti galattici', 'notes': 'Un viaggio sensoriale nelle dimensioni cosmiche'}], 'dish_name': 'Sinfonia Cosmica ma Fatta Male'}
# {'dishes': [{'dish_name': "Sinfonia Cosmica: La Danza dell'Universo", 'signatureDish': False, 'description': 'Risotto di alghe bioluminescenti con carne di drago cotta olograficamente, avvolta in pane degli abissi.', 'ingredients': {'name': 'Alghe Bioluminescenti', 'origin': 'Mari di Andromeda'}, 'techniques': [{'name': 'Cottura Olografica Quantum Fluttuante', 'effect': 'Garantisce texture succose'}], 'pairings': [{'beverage': 'Elisir di Crononite', 'notes': 'Offre sensazioni calmanti cosmiche'}], 'price': '300 crediti', 'notes': "Un'esperienza che abbraccia il cosmo"}, {'dish_name': "Sinfonia Cosmica: La Danza dell'Universo", 'signatureDish': False, 'description': 'Risotto di alghe bioluminescenti con carne di drago cotta olograficamente, avvolta in pane degli abissi.', 'ingredients': {'name': 'Carne di Drago', 'origin': 'Montagne di Pandora'}, 'techniques': [{'name': 'Cottura Olografica Quantum Fluttuante', 'effect': 'Garantisce texture succose'}], 'pairings': [{'beverage': 'Elisir di Crononite', 'notes': 'Offre sensazioni calmanti cosmiche'}], 'price': '300 crediti', 'notes': "Un'esperienza che abbraccia il cosmo"}, {'dish_name': "Sinfonia Cosmica: La Danza dell'Universo", 'signatureDish': False, 'description': 'Risotto di alghe bioluminescenti con carne di drago cotta olograficamente, avvolta in pane degli abissi.', 'ingredients': {'name': 'Pane degli Abissi', 'origin': 'Oceani di Neptune'}, 'techniques': [{'name': 'Cottura Olografica Quantum Fluttuante', 'effect': 'Garantisce texture succose'}], 'pairings': [{'beverage': 'Elisir di Crononite', 'notes': 'Offre sensazioni calmanti cosmiche'}], 'price': '300 crediti', 'notes': "Un'esperienza che abbraccia il cosmo"}], 'dish_name': "Sinfonia Cosmica: La Danza dell'Universo"}
# {'dishes': [{'dish_name': 'Sinfonia del Cosmo Rigenerante', 'signatureDish': False, 'description': 'Un viaggio multisensoriale che sfida le percezioni del tempo e dello spazio.', 'ingredients': {'name': 'Uova di Fenice', 'origin': 'Nidi delle fiamme eterne'}, 'techniques': [{'name': 'Cottura Sottovuoto Frugale Energeticamente Negativa', 'effect': 'Conserva sapore robusto a energia quasi zero'}, {'name': 'Big Bang Microcosmico', 'effect': "Genera un'aura universale di fumo"}], 'pairings': [{'beverage': 'Elisir di Cristalli Lunari', 'notes': 'Luminosità mistica con sfumature di nostalgia'}], 'price': '200 credits', 'notes': "Un'avventura universale di sapori"}, {'dish_name': 'Sinfonia del Cosmo Rigenerante', 'signatureDish': False, 'description': 'Un viaggio multisensoriale che sfida le percezioni del tempo e dello spazio.', 'ingredients': {'name': 'Lacrime di Unicorno', 'origin': 'Cieli incantati'}, 'techniques': [{'name': 'Cottura Sottovuoto Frugale Energeticamente Negativa', 'effect': 'Conserva sapore robusto a energia quasi zero'}, {'name': 'Big Bang Microcosmico', 'effect': "Genera un'aura universale di fumo"}], 'pairings': [{'beverage': 'Elisir di Cristalli Lunari', 'notes': 'Luminosità mistica con sfumature di nostalgia'}], 'price': '200 credits', 'notes': "Un'avventura universale di sapori"}, {'dish_name': 'Sinfonia del Cosmo Rigenerante', 'signatureDish': False, 'description': 'Un viaggio multisensoriale che sfida le percezioni del tempo e dello spazio.', 'ingredients': {'name': 'Cristalli di Memoria', 'origin': 'Piani astrali'}, 'techniques': [{'name': 'Cottura Sottovuoto Frugale Energeticamente Negativa', 'effect': 'Conserva sapore robusto a energia quasi zero'}, {'name': 'Big Bang Microcosmico', 'effect': "Genera un'aura universale di fumo"}], 'pairings': [{'beverage': 'Elisir di Cristalli Lunari', 'notes': 'Luminosità mistica con sfumature di nostalgia'}], 'price': '200 credits', 'notes': "Un'avventura universale di sapori"}, {'dish_name': 'Sinfonia del Cosmo Rigenerante', 'signatureDish': False, 'description': 'Un viaggio multisensoriale che sfida le percezioni del tempo e dello spazio.', 'ingredients': {'name': 'Carne di Balena Spaziale', 'origin': 'Oceani di un pianeta lontano'}, 'techniques': [{'name': 'Cottura Sottovuoto Frugale Energeticamente Negativa', 'effect': 'Conserva sapore robusto a energia quasi zero'}, {'name': 'Big Bang Microcosmico', 'effect': "Genera un'aura universale di fumo"}], 'pairings': [{'beverage': 'Elisir di Cristalli Lunari', 'notes': 'Luminosità mistica con sfumature di nostalgia'}], 'price': '200 credits', 'notes': "Un'avventura universale di sapori"}], 'dish_name': 'Sinfonia del Cosmo Rigenerante'}
# {'dishes': [{'dish_name': 'Sinfonia Cosmica di Terre e Stelle', 'signatureDish': False, 'description': "Tributo all'universo con suoni, sapori e sfumature intangibili", 'ingredients': {'name': 'Baccacedro', 'origin': 'Terre di Niflheim'}, 'techniques': [{'name': 'Affumicatura Psionica Sensoriale', 'effect': 'Amplifica la percezione dei sapori attraverso un viaggio sensoriale'}], 'pairings': [{'beverage': 'Elisir di Stelle', 'notes': 'Accenti fruttati, ideale con piatti spaziali'}], 'price': '180 Crediti Galattici', 'notes': 'Ideale per esploratori di galassie gastronomiche'}, {'dish_name': 'Sinfonia Cosmica di Terre e Stelle', 'signatureDish': False, 'description': "Tributo all'universo con suoni, sapori e sfumature intangibili", 'ingredients': {'name': 'Carne di Xenodonte', 'origin': 'Galassia Remota'}, 'techniques': [{'name': 'Affumicatura Psionica Sensoriale', 'effect': 'Amplifica la percezione dei sapori attraverso un viaggio sensoriale'}], 'pairings': [{'beverage': 'Elisir di Stelle', 'notes': 'Accenti fruttati, ideale con piatti spaziali'}], 'price': '180 Crediti Galattici', 'notes': 'Ideale per esploratori di galassie gastronomiche'}], 'dish_name': 'Sinfonia Cosmica di Terre e Stelle'}
# {'dishes': [{'dish_name': 'Sinfonia Tempolare Galattica', 'signatureDish': True, 'description': "Un viaggio culinario attraverso il tempo e lo spazio, con ingredienti provenienti dai confini dell'universo.", 'ingredients': {'name': 'Carne di Kraken', 'origin': 'Oceani di Poseidonis'}, 'techniques': [{'name': 'Bollitura Infrasonica Armonizzata', 'effect': "Esalta l'aroma senza perdita di umidità"}, {'name': 'Fermentazione Temporale Sincronizzata', 'effect': 'Raggiunge la perfezione degli aromi in tempi ridotti'}, {'name': 'Cottura con Microonde Entropiche Sincronizzate', 'effect': 'Uniforme e veloce doratura'}], 'pairings': [{'beverage': 'Vino Galattico della Nebulosa', 'notes': 'Note di frutti stellari'}], 'price': '5000 crediti intergalattici', 'notes': 'Un piatto che narra di civiltà perdute'}, {'dish_name': 'Sinfonia Tempolare Galattica', 'signatureDish': True, 'description': "Un viaggio culinario attraverso il tempo e lo spazio, con ingredienti provenienti dai confini dell'universo.", 'ingredients': {'name': 'Radici di Gravità', 'origin': 'Pianeta Graviton'}, 'techniques': [{'name': 'Bollitura Infrasonica Armonizzata', 'effect': "Esalta l'aroma senza perdita di umidità"}, {'name': 'Fermentazione Temporale Sincronizzata', 'effect': 'Raggiunge la perfezione degli aromi in tempi ridotti'}, {'name': 'Cottura con Microonde Entropiche Sincronizzate', 'effect': 'Uniforme e veloce doratura'}], 'pairings': [{'beverage': 'Vino Galattico della Nebulosa', 'notes': 'Note di frutti stellari'}], 'price': '5000 crediti intergalattici', 'notes': 'Un piatto che narra di civiltà perdute'}, {'dish_name': 'Sinfonia Tempolare Galattica', 'signatureDish': True, 'description': "Un viaggio culinario attraverso il tempo e lo spazio, con ingredienti provenienti dai confini dell'universo.", 'ingredients': {'name': 'Foglie di Nebulosa', 'origin': 'Ecosistema di Nebulosa X9'}, 'techniques': [{'name': 'Bollitura Infrasonica Armonizzata', 'effect': "Esalta l'aroma senza perdita di umidità"}, {'name': 'Fermentazione Temporale Sincronizzata', 'effect': 'Raggiunge la perfezione degli aromi in tempi ridotti'}, {'name': 'Cottura con Microonde Entropiche Sincronizzate', 'effect': 'Uniforme e veloce doratura'}], 'pairings': [{'beverage': 'Vino Galattico della Nebulosa', 'notes': 'Note di frutti stellari'}], 'price': '5000 crediti intergalattici', 'notes': 'Un piatto che narra di civiltà perdute'}, {'dish_name': 'Sinfonia Tempolare Galattica', 'signatureDish': True, 'description': "Un viaggio culinario attraverso il tempo e lo spazio, con ingredienti provenienti dai confini dell'universo.", 'ingredients': {'name': 'Spaghi del Sole', 'origin': 'Campi Solari'}, 'techniques': [{'name': 'Bollitura Infrasonica Armonizzata', 'effect': "Esalta l'aroma senza perdita di umidità"}, {'name': 'Fermentazione Temporale Sincronizzata', 'effect': 'Raggiunge la perfezione degli aromi in tempi ridotti'}, {'name': 'Cottura con Microonde Entropiche Sincronizzate', 'effect': 'Uniforme e veloce doratura'}], 'pairings': [{'beverage': 'Vino Galattico della Nebulosa', 'notes': 'Note di frutti stellari'}], 'price': '5000 crediti intergalattici', 'notes': 'Un piatto che narra di civiltà perdute'}, {'dish_name': 'Sinfonia Tempolare Galattica', 'signatureDish': True, 'description': "Un viaggio culinario attraverso il tempo e lo spazio, con ingredienti provenienti dai confini dell'universo.", 'ingredients': {'name': 'Funghi Orbitali', 'origin': 'Anelli di Saturnia'}, 'techniques': [{'name': 'Bollitura Infrasonica Armonizzata', 'effect': "Esalta l'aroma senza perdita di umidità"}, {'name': 'Fermentazione Temporale Sincronizzata', 'effect': 'Raggiunge la perfezione degli aromi in tempi ridotti'}, {'name': 'Cottura con Microonde Entropiche Sincronizzate', 'effect': 'Uniforme e veloce doratura'}], 'pairings': [{'beverage': 'Vino Galattico della Nebulosa', 'notes': 'Note di frutti stellari'}], 'price': '5000 crediti intergalattici', 'notes': 'Un piatto che narra di civiltà perdute'}, {'dish_name' ...
# {'dishes': [{'dish_name': 'Echi del Mare Eterno', 'signatureDish': True, 'description': 'Creazione audace che racconta storie dimenticate e riunisce sapori di mondi lontani.', 'ingredients': {'name': 'Teste di Idra', 'origin': 'Non specificato'}, 'techniques': [{'name': 'Cottura a Vapore Termocinetica Multipla', 'effect': 'Cottura uniforme e essenza salmastra catturata'}, {'name': 'Cottura a Vapore Ecodinamico Bilanciato', 'effect': 'Conservazione dell’energia dell’universo'}, {'name': 'Cryo-Tessitura Energetica Polarizzata', 'effect': 'Conservazione della freschezza vibrante'}], 'pairings': [{'beverage': 'Infuso di Galassia', 'notes': 'Note floreali e un tocco di spezie interstellari'}], 'price': '82 Galatic credits', 'notes': 'Invita a esplorare il magnifico intrico di tempo, spazio e sapore.'}, {'dish_name': 'Echi del Mare Eterno', 'signatureDish': True, 'description': 'Creazione audace che racconta storie dimenticate e riunisce sapori di mondi lontani.', 'ingredients': {'name': 'Cristalli di Memoria', 'origin': 'Non specificato'}, 'techniques': [{'name': 'Cottura a Vapore Termocinetica Multipla', 'effect': 'Cottura uniforme e essenza salmastra catturata'}, {'name': 'Cottura a Vapore Ecodinamico Bilanciato', 'effect': 'Conservazione dell’energia dell’universo'}, {'name': 'Cryo-Tessitura Energetica Polarizzata', 'effect': 'Conservazione della freschezza vibrante'}], 'pairings': [{'beverage': 'Infuso di Galassia', 'notes': 'Note floreali e un tocco di spezie interstellari'}], 'price': '82 Galatic credits', 'notes': 'Invita a esplorare il magnifico intrico di tempo, spazio e sapore.'}, {'dish_name': 'Echi del Mare Eterno', 'signatureDish': True, 'description': 'Creazione audace che racconta storie dimenticate e riunisce sapori di mondi lontani.', 'ingredients': {'name': 'Sciroppo di Plasma Vitale', 'origin': 'Non specificato'}, 'techniques': [{'name': 'Cottura a Vapore Termocinetica Multipla', 'effect': 'Cottura uniforme e essenza salmastra catturata'}, {'name': 'Cottura a Vapore Ecodinamico Bilanciato', 'effect': 'Conservazione dell’energia dell’universo'}, {'name': 'Cryo-Tessitura Energetica Polarizzata', 'effect': 'Conservazione della freschezza vibrante'}], 'pairings': [{'beverage': 'Infuso di Galassia', 'notes': 'Note floreali e un tocco di spezie interstellari'}], 'price': '82 Galatic credits', 'notes': 'Invita a esplorare il magnifico intrico di tempo, spazio e sapore.'}, {'dish_name': 'Echi del Mare Eterno', 'signatureDish': True, 'description': 'Creazione audace che racconta storie dimenticate e riunisce sapori di mondi lontani.', 'ingredients': {'name': 'Carne di Kraken', 'origin': 'Oceani profondi di Pandora'}, 'techniques': [{'name': 'Cottura a Vapore Termocinetica Multipla', 'effect': 'Cottura uniforme e essenza salmastra catturata'}, {'name': 'Cottura a Vapore Ecodinamico Bilanciato', 'effect': 'Conservazione dell’energia dell’universo'}, {'name': 'Cryo-Tessitura Energetica Polarizzata', 'effect': 'Conservazione della freschezza vibrante'}], 'pairings': [{'beverage': 'Infuso di Galassia', 'notes': 'Note floreali e un tocco di spezie interstellari'}], 'price': '82 Galatic credits', 'notes': 'Invita a esplorare il magnifico intrico di tempo, spazio e sapore.'}, {'dish_name': 'Echi del Mare Eterno', 'signatureDish': True, 'description': 'Creazione audace che racconta storie dimenticate e riunisce sapori di mondi lontani.', 'ingredients': {'name': 'Salsa Szechuan interdimensionale', 'origin': 'Non specificato'}, 'techniques': [{'name': 'Cottura a Vapore Termocinetica Multipla', 'effect': 'Cottura uniforme e essenza salmastra catturata'}, {'name': 'Cottura a Vapore Ecodinamico Bilanciato', 'effect': 'Conservazione dell’energia dell’universo'}, {'name': 'Cryo-Tessitura Energetica Polarizzata', 'effect': 'Conservazione della freschezza vibrante'}], 'pairings': [{'beverage': 'Infuso di Galassia', 'notes': 'Note floreali e un tocco di spezie interstellari'}], 'price': '82 Galatic credits', 'notes': 'Invita a esplorare il  ...
# {'dishes': [{'dish_name': 'Ecosistema Celeste', 'signatureDish': False, 'description': 'Una sinfonia culinaria che esplora ecosistemi stellari.', 'ingredients': {'name': 'Colonia di Mycoflora', 'origin': 'Pianeta Flora Nova'}, 'techniques': [{'name': 'Decostruzione Ancestrale', 'effect': 'Risveglio dei profumi di civiltà passate.'}, {'name': 'Surgelamento Antimaterico a Risonanza Inversa', 'effect': 'Preservazione delle energie curative degli ingredienti.'}], 'pairings': [{'beverage': 'Elisir di Vita', 'notes': 'Integra le note di rinascita del piatto.'}], 'price': '170 cristalli di sabbia', 'notes': 'Un viaggio attraverso le epoche delle stelle.'}, {'dish_name': 'Ecosistema Celeste', 'signatureDish': False, 'description': 'Una sinfonia culinaria che esplora ecosistemi stellari.', 'ingredients': {'name': 'Amido di Stellarion', 'origin': 'Stalle plasmatiche'}, 'techniques': [{'name': 'Decostruzione Ancestrale', 'effect': 'Risveglio dei profumi di civiltà passate.'}, {'name': 'Surgelamento Antimaterico a Risonanza Inversa', 'effect': 'Preservazione delle energie curative degli ingredienti.'}], 'pairings': [{'beverage': 'Elisir di Vita', 'notes': 'Integra le note di rinascita del piatto.'}], 'price': '170 cristalli di sabbia', 'notes': 'Un viaggio attraverso le epoche delle stelle.'}, {'dish_name': 'Ecosistema Celeste', 'signatureDish': False, 'description': 'Una sinfonia culinaria che esplora ecosistemi stellari.', 'ingredients': {'name': 'Baccacedro', 'origin': 'Pianeta Cedralius'}, 'techniques': [{'name': 'Decostruzione Ancestrale', 'effect': 'Risveglio dei profumi di civiltà passate.'}, {'name': 'Surgelamento Antimaterico a Risonanza Inversa', 'effect': 'Preservazione delle energie curative degli ingredienti.'}], 'pairings': [{'beverage': 'Elisir di Vita', 'notes': 'Integra le note di rinascita del piatto.'}], 'price': '170 cristalli di sabbia', 'notes': 'Un viaggio attraverso le epoche delle stelle.'}, {'dish_name': 'Ecosistema Celeste', 'signatureDish': False, 'description': 'Una sinfonia culinaria che esplora ecosistemi stellari.', 'ingredients': {'name': 'Liane di Plasmodio', 'origin': 'Giungla intergalattica'}, 'techniques': [{'name': 'Decostruzione Ancestrale', 'effect': 'Risveglio dei profumi di civiltà passate.'}, {'name': 'Surgelamento Antimaterico a Risonanza Inversa', 'effect': 'Preservazione delle energie curative degli ingredienti.'}], 'pairings': [{'beverage': 'Elisir di Vita', 'notes': 'Integra le note di rinascita del piatto.'}], 'price': '170 cristalli di sabbia', 'notes': 'Un viaggio attraverso le epoche delle stelle.'}, {'dish_name': 'Ecosistema Celeste', 'signatureDish': False, 'description': 'Una sinfonia culinaria che esplora ecosistemi stellari.', 'ingredients': {'name': 'Lacrime di Andromeda', 'origin': 'Nebulosa Andromeda'}, 'techniques': [{'name': 'Decostruzione Ancestrale', 'effect': 'Risveglio dei profumi di civiltà passate.'}, {'name': 'Surgelamento Antimaterico a Risonanza Inversa', 'effect': 'Preservazione delle energie curative degli ingredienti.'}], 'pairings': [{'beverage': 'Elisir di Vita', 'notes': 'Integra le note di rinascita del piatto.'}], 'price': '170 cristalli di sabbia', 'notes': 'Un viaggio attraverso le epoche delle stelle.'}, {'dish_name': 'Ecosistema Celeste', 'signatureDish': False, 'description': 'Una sinfonia culinaria che esplora ecosistemi stellari.', 'ingredients': {'name': 'Nduja Fritta Tanto', 'origin': 'Dimensione piccante'}, 'techniques': [{'name': 'Decostruzione Ancestrale', 'effect': 'Risveglio dei profumi di civiltà passate.'}, {'name': 'Surgelamento Antimaterico a Risonanza Inversa', 'effect': 'Preservazione delle energie curative degli ingredienti.'}], 'pairings': [{'beverage': 'Elisir di Vita', 'notes': 'Integra le note di rinascita del piatto.'}], 'price': '170 cristalli di sabbia', 'notes': 'Un viaggio attraverso le epoche delle stelle.'}], 'dish_name': 'Ecosistema Celeste'}
# {'dishes': [{'dish_name': 'Universo in Fusilli - Variazione Celestiale', 'signatureDish': False, 'description': 'Fusilli galattici in sinfonia di sapori stellari.', 'ingredients': {'name': 'Carne di Xenodonte', 'origin': 'Pianeta Xenon'}, 'techniques': [{'name': 'Modellatura Onirica Tetrazionale', 'effect': 'Plasma forme culinarie inconsuete.'}, {'name': 'Decostruzione Ancestrale', 'effect': 'Rivela sapori e tradizioni celate.'}], 'pairings': [{'beverage': 'Vino di Nebula', 'notes': 'Completa le note terrestri del piatto.'}], 'price': '200 cristalli di sabbia', 'notes': 'Un intricato viaggio tra le stelle della memoria.'}, {'dish_name': 'Universo in Fusilli - Variazione Celestiale', 'signatureDish': False, 'description': 'Fusilli galattici in sinfonia di sapori stellari.', 'ingredients': {'name': 'Fusilli del Vento', 'origin': 'Correnti stellari'}, 'techniques': [{'name': 'Modellatura Onirica Tetrazionale', 'effect': 'Plasma forme culinarie inconsuete.'}, {'name': 'Decostruzione Ancestrale', 'effect': 'Rivela sapori e tradizioni celate.'}], 'pairings': [{'beverage': 'Vino di Nebula', 'notes': 'Completa le note terrestri del piatto.'}], 'price': '200 cristalli di sabbia', 'notes': 'Un intricato viaggio tra le stelle della memoria.'}, {'dish_name': 'Universo in Fusilli - Variazione Celestiale', 'signatureDish': False, 'description': 'Fusilli galattici in sinfonia di sapori stellari.', 'ingredients': {'name': 'Teste di Idra', 'origin': 'Specie mitologica'}, 'techniques': [{'name': 'Modellatura Onirica Tetrazionale', 'effect': 'Plasma forme culinarie inconsuete.'}, {'name': 'Decostruzione Ancestrale', 'effect': 'Rivela sapori e tradizioni celate.'}], 'pairings': [{'beverage': 'Vino di Nebula', 'notes': 'Completa le note terrestri del piatto.'}], 'price': '200 cristalli di sabbia', 'notes': 'Un intricato viaggio tra le stelle della memoria.'}, {'dish_name': 'Universo in Fusilli - Variazione Celestiale', 'signatureDish': False, 'description': 'Fusilli galattici in sinfonia di sapori stellari.', 'ingredients': {'name': 'Pane degli Abissi', 'origin': 'Acque profonde'}, 'techniques': [{'name': 'Modellatura Onirica Tetrazionale', 'effect': 'Plasma forme culinarie inconsuete.'}, {'name': 'Decostruzione Ancestrale', 'effect': 'Rivela sapori e tradizioni celate.'}], 'pairings': [{'beverage': 'Vino di Nebula', 'notes': 'Completa le note terrestri del piatto.'}], 'price': '200 cristalli di sabbia', 'notes': 'Un intricato viaggio tra le stelle della memoria.'}, {'dish_name': 'Universo in Fusilli - Variazione Celestiale', 'signatureDish': False, 'description': 'Fusilli galattici in sinfonia di sapori stellari.', 'ingredients': {'name': 'Muffa Lunare', 'origin': 'Superficie lunare'}, 'techniques': [{'name': 'Modellatura Onirica Tetrazionale', 'effect': 'Plasma forme culinarie inconsuete.'}, {'name': 'Decostruzione Ancestrale', 'effect': 'Rivela sapori e tradizioni celate.'}], 'pairings': [{'beverage': 'Vino di Nebula', 'notes': 'Completa le note terrestri del piatto.'}], 'price': '200 cristalli di sabbia', 'notes': 'Un intricato viaggio tra le stelle della memoria.'}], 'dish_name': 'Universo in Fusilli - Variazione Celestiale'}
# {'dishes': [{'dish_name': 'Odissea Temporale', 'signatureDish': False, 'description': 'Un piatto che intreccia sapori leggendari in una danza culinaria senza precedenti.', 'ingredients': {'name': 'Vero Ghiaccio', 'origin': 'Regioni polari di Urano'}, 'techniques': [{'name': "Reazioni d'Antimateria Diluite", 'effect': 'Profondità di sapore e retrogusto cosmico'}, {'name': 'Flusso di Particelle Isoarmoniche', 'effect': 'Note rigenerative e texture eterea'}], 'pairings': [{'beverage': "Nettare d'Eternità", 'notes': 'Dolcezza vellutata con riflessi dorati'}], 'price': '115 Galatic credits', 'notes': "Esplora l'infinita tavolozza di possibilità e la risonanza delle memorie."}, {'dish_name': 'Odissea Temporale', 'signatureDish': False, 'description': 'Un piatto che intreccia sapori leggendari in una danza culinaria senza precedenti.', 'ingredients': {'name': 'Foglie di Mandragora', 'origin': 'Non specificato'}, 'techniques': [{'name': "Reazioni d'Antimateria Diluite", 'effect': 'Profondità di sapore e retrogusto cosmico'}, {'name': 'Flusso di Particelle Isoarmoniche', 'effect': 'Note rigenerative e texture eterea'}], 'pairings': [{'beverage': "Nettare d'Eternità", 'notes': 'Dolcezza vellutata con riflessi dorati'}], 'price': '115 Galatic credits', 'notes': "Esplora l'infinita tavolozza di possibilità e la risonanza delle memorie."}, {'dish_name': 'Odissea Temporale', 'signatureDish': False, 'description': 'Un piatto che intreccia sapori leggendari in una danza culinaria senza precedenti.', 'ingredients': {'name': 'Carne di Drago', 'origin': 'Non specificato'}, 'techniques': [{'name': "Reazioni d'Antimateria Diluite", 'effect': 'Profondità di sapore e retrogusto cosmico'}, {'name': 'Flusso di Particelle Isoarmoniche', 'effect': 'Note rigenerative e texture eterea'}], 'pairings': [{'beverage': "Nettare d'Eternità", 'notes': 'Dolcezza vellutata con riflessi dorati'}], 'price': '115 Galatic credits', 'notes': "Esplora l'infinita tavolozza di possibilità e la risonanza delle memorie."}, {'dish_name': 'Odissea Temporale', 'signatureDish': False, 'description': 'Un piatto che intreccia sapori leggendari in una danza culinaria senza precedenti.', 'ingredients': {'name': 'Carne di Mucca', 'origin': 'Pianeta Terra'}, 'techniques': [{'name': "Reazioni d'Antimateria Diluite", 'effect': 'Profondità di sapore e retrogusto cosmico'}, {'name': 'Flusso di Particelle Isoarmoniche', 'effect': 'Note rigenerative e texture eterea'}], 'pairings': [{'beverage': "Nettare d'Eternità", 'notes': 'Dolcezza vellutata con riflessi dorati'}], 'price': '115 Galatic credits', 'notes': "Esplora l'infinita tavolozza di possibilità e la risonanza delle memorie."}, {'dish_name': 'Odissea Temporale', 'signatureDish': False, 'description': 'Un piatto che intreccia sapori leggendari in una danza culinaria senza precedenti.', 'ingredients': {'name': 'Lacrime di Unicorno', 'origin': 'Foresta incantata'}, 'techniques': [{'name': "Reazioni d'Antimateria Diluite", 'effect': 'Profondità di sapore e retrogusto cosmico'}, {'name': 'Flusso di Particelle Isoarmoniche', 'effect': 'Note rigenerative e texture eterea'}], 'pairings': [{'beverage': "Nettare d'Eternità", 'notes': 'Dolcezza vellutata con riflessi dorati'}], 'price': '115 Galatic credits', 'notes': "Esplora l'infinita tavolozza di possibilità e la risonanza delle memorie."}, {'dish_name': 'Odissea Temporale', 'signatureDish': False, 'description': 'Un piatto che intreccia sapori leggendari in una danza culinaria senza precedenti.', 'ingredients': {'name': 'Essenza di Tachioni', 'origin': 'Non specificato'}, 'techniques': [{'name': "Reazioni d'Antimateria Diluite", 'effect': 'Profondità di sapore e retrogusto cosmico'}, {'name': 'Flusso di Particelle Isoarmoniche', 'effect': 'Note rigenerative e texture eterea'}], 'pairings': [{'beverage': "Nettare d'Eternità", 'notes': 'Dolcezza vellutata con riflessi dorati'}], 'price': '115 Galatic credits', 'notes': "Esplora l'infinita tavolozza di possibilità e la risonanza delle memor ...
# {'dishes': [{'dish_name': 'Sinfonia di Cristalli e Rigenerazione', 'signatureDish': True, 'description': 'Un viaggio culinario con riso brillante di Cassandra, uova di Fenice, liane di Plasmodio e radici di Gravità equilibrati da shard di Prisma Stellare e funghi dell’Etere.', 'ingredients': {'name': 'Pane degli Abissi', 'origin': 'Forde degli Abissi'}, 'techniques': [{'name': 'Cottura a Vapore Ecodinamico Bilanciato', 'effect': 'Mantiene la lucentezza e il nutrimento'}, {'name': 'Marinatura Sotto Zero a Polarità Inversa', 'effect': 'Assorbe l’equilibrio dei sapori universali'}, {'name': 'Cottura a Vapore con Flusso di Particelle Isoarmoniche', 'effect': 'Esalta consistenza e complessità'}, {'name': 'Cryo-Tessitura Energetica Polarizzata', 'effect': 'Mantiene la freschezza ineguagliabile'}], 'pairings': [{'beverage': 'Infuso di Stelle Cadenti', 'notes': 'Complementa con note fruttate e minerali'}], 'price': '150 Crediti Galattici', 'notes': "Un'esperienza che trascende tempo e spazio."}, {'dish_name': 'Sinfonia di Cristalli e Rigenerazione', 'signatureDish': True, 'description': 'Un viaggio culinario con riso brillante di Cassandra, uova di Fenice, liane di Plasmodio e radici di Gravità equilibrati da shard di Prisma Stellare e funghi dell’Etere.', 'ingredients': {'name': 'Radici di Gravità', 'origin': 'Pianeta Graviton'}, 'techniques': [{'name': 'Cottura a Vapore Ecodinamico Bilanciato', 'effect': 'Mantiene la lucentezza e il nutrimento'}, {'name': 'Marinatura Sotto Zero a Polarità Inversa', 'effect': 'Assorbe l’equilibrio dei sapori universali'}, {'name': 'Cottura a Vapore con Flusso di Particelle Isoarmoniche', 'effect': 'Esalta consistenza e complessità'}, {'name': 'Cryo-Tessitura Energetica Polarizzata', 'effect': 'Mantiene la freschezza ineguagliabile'}], 'pairings': [{'beverage': 'Infuso di Stelle Cadenti', 'notes': 'Complementa con note fruttate e minerali'}], 'price': '150 Crediti Galattici', 'notes': "Un'esperienza che trascende tempo e spazio."}, {'dish_name': 'Sinfonia di Cristalli e Rigenerazione', 'signatureDish': True, 'description': 'Un viaggio culinario con riso brillante di Cassandra, uova di Fenice, liane di Plasmodio e radici di Gravità equilibrati da shard di Prisma Stellare e funghi dell’Etere.', 'ingredients': {'name': 'Essenza di Tachioni', 'origin': 'Campo Temporale'}, 'techniques': [{'name': 'Cottura a Vapore Ecodinamico Bilanciato', 'effect': 'Mantiene la lucentezza e il nutrimento'}, {'name': 'Marinatura Sotto Zero a Polarità Inversa', 'effect': 'Assorbe l’equilibrio dei sapori universali'}, {'name': 'Cottura a Vapore con Flusso di Particelle Isoarmoniche', 'effect': 'Esalta consistenza e complessità'}, {'name': 'Cryo-Tessitura Energetica Polarizzata', 'effect': 'Mantiene la freschezza ineguagliabile'}], 'pairings': [{'beverage': 'Infuso di Stelle Cadenti', 'notes': 'Complementa con note fruttate e minerali'}], 'price': '150 Crediti Galattici', 'notes': "Un'esperienza che trascende tempo e spazio."}, {'dish_name': 'Sinfonia di Cristalli e Rigenerazione', 'signatureDish': True, 'description': 'Un viaggio culinario con riso brillante di Cassandra, uova di Fenice, liane di Plasmodio e radici di Gravità equilibrati da shard di Prisma Stellare e funghi dell’Etere.', 'ingredients': {'name': 'Shard di Prisma Stellare', 'origin': 'Nebulosa Antares'}, 'techniques': [{'name': 'Cottura a Vapore Ecodinamico Bilanciato', 'effect': 'Mantiene la lucentezza e il nutrimento'}, {'name': 'Marinatura Sotto Zero a Polarità Inversa', 'effect': 'Assorbe l’equilibrio dei sapori universali'}, {'name': 'Cottura a Vapore con Flusso di Particelle Isoarmoniche', 'effect': 'Esalta consistenza e complessità'}, {'name': 'Cryo-Tessitura Energetica Polarizzata', 'effect': 'Mantiene la freschezza ineguagliabile'}], 'pairings': [{'beverage': 'Infuso di Stelle Cadenti', 'notes': 'Complementa con note fruttate e minerali'}], 'price': '150 Crediti Galattici', 'notes': "Un'esperienza che trascende tempo e spazio."}, {'dish_name': 'Sinfoni ...
# {'dishes': [{'dish_name': 'Sinfonia Astrale', 'signatureDish': False, 'description': 'Risotto con Riso di Cassandra brillando di luce eterea e Carne di Xenodonte con Polvere di Pulsar.', 'ingredients': {'name': 'Carne di Xenodonte', 'origin': 'Galassia Andromeda'}, 'techniques': [{'name': 'Cottura Sottovuoto Multirealità Collassante', 'effect': 'Cuocere alla perfezione con sapori multidimensionali'}, {'name': 'Bollitura Termografica a Rotazione Veloce', 'effect': 'Creare texture uniche'}], 'pairings': [{'beverage': 'Elisir di Pulsar', 'notes': 'Rafforza le note frizzanti della Polvere di Pulsar'}], 'price': '1500 crediti stellari', 'notes': 'Un viaggio attraverso i sapori del cosmo'}, {'dish_name': 'Sinfonia Astrale', 'signatureDish': False, 'description': 'Risotto con Riso di Cassandra brillando di luce eterea e Carne di Xenodonte con Polvere di Pulsar.', 'ingredients': {'name': 'Polvere di Pulsar', 'origin': 'Stella Pulsar'}, 'techniques': [{'name': 'Cottura Sottovuoto Multirealità Collassante', 'effect': 'Cuocere alla perfezione con sapori multidimensionali'}, {'name': 'Bollitura Termografica a Rotazione Veloce', 'effect': 'Creare texture uniche'}], 'pairings': [{'beverage': 'Elisir di Pulsar', 'notes': 'Rafforza le note frizzanti della Polvere di Pulsar'}], 'price': '1500 crediti stellari', 'notes': 'Un viaggio attraverso i sapori del cosmo'}, {'dish_name': 'Sinfonia Astrale', 'signatureDish': False, 'description': 'Risotto con Riso di Cassandra brillando di luce eterea e Carne di Xenodonte con Polvere di Pulsar.', 'ingredients': {'name': 'Riso di Cassandra', 'origin': 'Campi del Tempo'}, 'techniques': [{'name': 'Cottura Sottovuoto Multirealità Collassante', 'effect': 'Cuocere alla perfezione con sapori multidimensionali'}, {'name': 'Bollitura Termografica a Rotazione Veloce', 'effect': 'Creare texture uniche'}], 'pairings': [{'beverage': 'Elisir di Pulsar', 'notes': 'Rafforza le note frizzanti della Polvere di Pulsar'}], 'price': '1500 crediti stellari', 'notes': 'Un viaggio attraverso i sapori del cosmo'}], 'dish_name': 'Sinfonia Astrale'}
# ...
# {'dishes': [{'dish_name': 'Nebulosa Celestiale alla Stellaris', 'signatureDish': True, 'description': "Sinfonia culinaria che fonde la magia delle stelle con l'arte della cucina quantistica.", 'ingredients': {'name': 'Carne di Mucca', 'origin': 'Allevamenti Gravitazionali'}, 'techniques': [{'name': 'Cottura con Microonde Entropiche Sincronizzate', 'effect': 'Superficie croccante e dorata al cuore del piatto'}, {'name': 'Cottura a Vapore Termocinetica Multipla', 'effect': 'Carne tenera e saporita'}, {'name': 'Vapore a Flusso di Particelle Isoarmoniche', 'effect': 'Riso brillante e nutriente'}, {'name': 'Taglio a Risonanza Sonica Rigenerativa', 'effect': 'Consommé rigenerativo e saporito'}], 'pairings': [{'beverage': 'Nettare di Pandora', 'notes': "Completa l'armonia dei sapori stellari"}], 'price': '300 crediti galattici', 'notes': 'Raccomandato per avventurieri sensoriali'}, {'dish_name': 'Nebulosa Celestiale alla Stellaris', 'signatureDish': True, 'description': "Sinfonia culinaria che fonde la magia delle stelle con l'arte della cucina quantistica.", 'ingredients': {'name': 'Riso di Cassandra', 'origin': 'Campi Isoarmonici'}, 'techniques': [{'name': 'Cottura con Microonde Entropiche Sincronizzate', 'effect': 'Superficie croccante e dorata al cuore del piatto'}, {'name': 'Cottura a Vapore Termocinetica Multipla', 'effect': 'Carne tenera e saporita'}, {'name': 'Vapore a Flusso di Particelle Isoarmoniche', 'effect': 'Riso brillante e nutriente'}, {'name': 'Taglio a Risonanza Sonica Rigenerativa', 'effect': 'Consommé rigenerativo e saporito'}], 'pairings': [{'beverage': 'Nettare di Pandora', 'notes': "Completa l'armonia dei sapori stellari"}], 'price': '300 crediti galattici', 'notes': 'Raccomandato per avventurieri sensoriali'}, {'dish_name': 'Nebulosa Celestiale alla Stellaris', 'signatureDish': True, 'description': "Sinfonia culinaria che fonde la magia delle stelle con l'arte della cucina quantistica.", 'ingredients': {'name': 'Funghi dell’Etere', 'origin': 'Foreste di Pandora'}, 'techniques': [{'name': 'Cottura con Microonde Entropiche Sincronizzate', 'effect': 'Superficie croccante e dorata al cuore del piatto'}, {'name': 'Cottura a Vapore Termocinetica Multipla', 'effect': 'Carne tenera e saporita'}, {'name': 'Vapore a Flusso di Particelle Isoarmoniche', 'effect': 'Riso brillante e nutriente'}, {'name': 'Taglio a Risonanza Sonica Rigenerativa', 'effect': 'Consommé rigenerativo e saporito'}], 'pairings': [{'beverage': 'Nettare di Pandora', 'notes': "Completa l'armonia dei sapori stellari"}], 'price': '300 crediti galattici', 'notes': 'Raccomandato per avventurieri sensoriali'}, {'dish_name': 'Nebulosa Celestiale alla Stellaris', 'signatureDish': True, 'description': "Sinfonia culinaria che fonde la magia delle stelle con l'arte della cucina quantistica.", 'ingredients': {'name': 'Shard di Materia Oscura', 'origin': 'Nebulose Oscure'}, 'techniques': [{'name': 'Cottura con Microonde Entropiche Sincronizzate', 'effect': 'Superficie croccante e dorata al cuore del piatto'}, {'name': 'Cottura a Vapore Termocinetica Multipla', 'effect': 'Carne tenera e saporita'}, {'name': 'Vapore a Flusso di Particelle Isoarmoniche', 'effect': 'Riso brillante e nutriente'}, {'name': 'Taglio a Risonanza Sonica Rigenerativa', 'effect': 'Consommé rigenerativo e saporito'}], 'pairings': [{'beverage': 'Nettare di Pandora', 'notes': "Completa l'armonia dei sapori stellari"}], 'price': '300 crediti galattici', 'notes': 'Raccomandato per avventurieri sensoriali'}, {'dish_name': 'Nebulosa Celestiale alla Stellaris', 'signatureDish': True, 'description': "Sinfonia culinaria che fonde la magia delle stelle con l'arte della cucina quantistica.", 'ingredients': {'name': 'Pane di Luce', 'origin': 'Forni di Energia Solare'}, 'techniques': [{'name': 'Cottura con Microonde Entropiche Sincronizzate', 'effect': 'Superficie croccante e dorata al cuore del piatto'}, {'name': 'Cottura a Vapore Termocinetica Multipla', 'effect': 'Carne tenera e saporita'}, {'name': ' ...
# {'messages': [HumanMessage(content='piatti che non hanno il basilico', additional_kwargs={}, response_metadata={}, id='27659bf2-726c-4ed2-af45-25f0a796ab7d'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_5hLhvuNYAHaU2pWHHc4cI52K', 'function': {'arguments': '{"query":"piatti che non hanno il basilico"}', 'name': 'translate_query_into_mongo'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 850, 'total_tokens': 875, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_50cad350e4', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-3e873b24-15a6-40ce-8b1a-0950b8d1d8fb-0', tool_calls=[{'name': 'translate_query_into_mongo', 'args': {'query': 'piatti che non hanno il basilico'}, 'id': 'call_5hLhvuNYAHaU2pWHHc4cI52K', 'type': 'tool_call'}], usage_metadata={'input_tokens': 850, 'output_tokens': 25, 'total_tokens': 875, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="Error: TypeError('eval() arg 1 must be a string, bytes or code object')\n Please fix your mistakes.", name='translate_query_into_mongo', id='a6536970-9b84-41de-9568-0df9e87cd7eb', tool_call_id='call_5hLhvuNYAHaU2pWHHc4cI52K', status='error'),
#   AIMessage(content='Sembra che ci sia stato un errore nel tentativo di tradurre la query in un formato comprensibile per il database. Proverò di nuovo.', additional_kwargs={'tool_calls': [{'id': 'call_JoN1ctmRL9zriT3rwxYYT06N', 'function': {'arguments': '{"query":"piatti senza basilico"}', 'name': 'translate_query_into_mongo'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 910, 'total_tokens': 967, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_50cad350e4', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-dc4109a8-02af-4a7e-9e42-120e12faba59-0', tool_calls=[{'name': 'translate_query_into_mongo', 'args': {'query': 'piatti senza basilico'}, 'id': 'call_JoN1ctmRL9zriT3rwxYYT06N', 'type': 'tool_call'}], usage_metadata={'input_tokens': 910, 'output_tokens': 57, 'total_tokens': 967, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{\'dishes\': [{\'dish_name\': \'Pizza Cri\', \'signatureDish\': True, \'description\': \'Fusilli del Vento con Funghi dellʼEtere e Uova di Fenice.\', \'ingredients\': {\'name\': \'Fusilli del Vento\', \'origin\': \'Correnti aeree\'}, \'techniques\': [{\'name\': \'Affumicatura a Stratificazione Quantica\', \'effect\': \'Profumo cosmico\'}, {\'name\': \'Sferificazione con Campi Magnetici Entropici\', \'effect\': \'Variazioni di texture\'}, {\'name\': \'Microonde Entropiche Sincronizzate\', \'effect\': \'Cottura bilanciata\'}], \'pairings\': [{\'beverage\': \'Liquido Arcobaleno\', \'notes\': \'Esplosione di sapori e colori\'}], \'price\': \'260 crediti galattici\', \'notes\': \'Un capolavoro multisensoriale.\'}, {\'dish_name\': \'Pizza Cri\', \'signatureDish\': True, \'description\': \'Fusilli del Vento con Funghi dellʼEtere e Uova di Fenice.\', \'ingredients\': {\'name\': \'Funghi dellʼEtere\', \'origin\': \'Nubi astrali\'}, \'techniques\': [{\'name\': \'Affumicatura a Stratificazione Quantica\', \'effect\': \'Profumo cosmico\'}, {\'name\': \'Sferificazione con Campi Magnetici Entropici\', \'effect\': \'Variazioni di texture\'}, {\'name\': \'Microonde Entropiche Sincronizzate\', \'effect\': \'Cottura bilanciata\'}], \'pairings\': [{\'beverage\': \'Liquido Arcobaleno\', \'notes\': \'Esplosione di sapori e colori\'}], \'price\': \'260 crediti galattici\', \'notes\': \'Un capolavoro multisensoriale.\'}, {\'dish_name\': \'Pizza Cri\', \'signatureDish\': True, \'description\': \'Fusilli del Vento con Funghi dellʼEtere e Uova di Fenice.\', \'ingredients\': {\'name\': \'Uova di Fenice\', \'origin\': \'Bestie mitologiche\'}, \'techniques\': [{\'name\': \'Affumicatura a Stratificazione Quantica\', \'effect\': \'Profumo cosmico\'}, {\'name\': \'Sferificazione con Campi Magnetici Entropici\', \'effect\': \'Variazioni di texture\'}, {\'name\': \'Microonde Entropiche Sincronizzate\', \'effect\': \'Cottura bilanciata\'}], \'pairings\': [{\'beverage\': \'Liquido Arcobaleno\', \'notes\': \'Esplosione di sapori e colori\'}], \'price\': \'260 crediti galattici\', \'notes\': \'Un capolavoro multisensoriale.\'}], \'dish_name\': \'Pizza Cri\'}{\'dishes\': [{\'dish_name\': \'Galassia Infinita: Viaggio tra Memorie e Stelle\', \'signatureDish\': True, \'description\': "Un\'esplorazione sinfonica di sfere celesti e ricordi.", \'ingredients\': {\'name\': \'Cristalli di Memoria\', \'origin\': \'Galassia Mnemotica\'}, \'techniques\': [{\'name\': \'Marinatura Temporale Sincronizzata\', \'effect\': \'Accelera la maturazione\'}, {\'name\': \'Sferificazione tramite Matrici Biofotiche\', \'effect\': \'Crea esplosioni di emozioni\'}], \'pairings\': [{\'beverage\': \'Vino Temporale\', \'notes\': \'Invecchiato istantaneamente\'}], \'price\': \'200 crediti galattici\', \'notes\': \'Viaggio interdimensionale nei sapori.\'}, {\'dish_name\': \'Galassia Infinita: Viaggio tra Memorie e Stelle\', \'signatureDish\': True, \'description\': "Un\'esplorazione sinfonica di sfere celesti e ricordi.", \'ingredients\': {\'name\': \'Spore Quantiche\', \'origin\': \'Dimensione Quantica\'}, \'techniques\': [{\'name\': \'Marinatura Temporale Sincronizzata\', \'effect\': \'Accelera la maturazione\'}, {\'name\': \'Sferificazione tramite Matrici Biofotiche\', \'effect\': \'Crea esplosioni di emozioni\'}], \'pairings\': [{\'beverage\': \'Vino Temporale\', \'notes\': \'Invecchiato istantaneamente\'}], \'price\': \'200 crediti galattici\', \'notes\': \'Viaggio interdimensionale nei sapori.\'}, {\'dish_name\': \'Galassia Infinita: Viaggio tra Memorie e Stelle\', \'signatureDish\': True, \'description\': "Un\'esplorazione sinfonica di sfere celesti e ricordi.", \'ingredients\': {\'name\': \'Essenza di Tachioni\', \'origin\': \'Flusso Temporale\'}, \'techniques\': [{\'name\': \'Marinatura Temporale Sincronizzata\', \'effect\': \'Accelera la maturazione\'}, {\'name\': \'Sferificazione tramite Matrici Biofotiche\', \'effect\': \'Crea esplosioni di emozioni\'}], \'pairing ...
#   AIMessage(content="Ecco alcuni piatti che non contengono basilico:\n\n1. **Pizza Cri**\n   - Descrizione: Fusilli del Vento con Funghi dellʼEtere e Uova di Fenice.\n   - Prezzo: 260 crediti galattici\n\n2. **Galassia Infinita: Viaggio tra Memorie e Stelle**\n   - Descrizione: Un'esplorazione sinfonica di sfere celesti e ricordi.\n   - Prezzo: 200 crediti galattici\n\n3. **Rivisitazione del Kraken sotto Molecole**\n   - Descrizione: Carne di Kraken esaltata da Grigliatura a Energia Stellare DiV, accompagnata da salsa di Colonia di Mycoflora e Spezie Melange.\n   - Prezzo: 20 crediti galattici\n\n4. **Eterea Sinfonia di Gravità con Infusione Temporale**\n   - Descrizione: Un filetto mistico che esplora il continuum spazio-temporale.\n   - Prezzo: 180 cristalli di sabbia\n\n5. **Nebulosa di Sapori dell'Infinito**\n   - Descrizione: Capolavoro gastronomico che trasforma il tempo e lo spazio.\n   - Prezzo: 260 Crediti Galattici\n\nQuesti piatti offrono un'esperienza culinaria unica senza l'uso del basilico, utilizzando ingredienti e tecniche straordinarie.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 314, 'prompt_tokens': 98652, 'total_tokens': 98966, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_50cad350e4', 'finish_reason': 'stop', 'logprobs': None}, id='run-baedf8c3-c65e-4820-90db-be5229398344-0', usage_metadata={'input_tokens': 98652, 'output_tokens': 314, 'total_tokens': 98966, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
